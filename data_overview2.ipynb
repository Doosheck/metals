# %%
import pandas as pd

# %% [markdown]
# ## Lithium

# %%
# Load lithium data
df_lithium = pd.read_csv('data/ALL_lithium_prices_cubic_spline.csv')
df_lithium = df_lithium.drop(columns=['LISAME'])
df_lithium['Date'] = pd.to_datetime(df_lithium['Date'])
# df_lithium = df_lithium[df_lithium['Date'] >= '2021-08-01']
df_lithium.head()
# Out:
#         Date  LIDALY  LICOMX  LILAMC  LIEALC  LIEABG  LILMEX
# 0 2017-05-10   20.92     NaN     NaN     NaN     NaN     NaN
# 1 2017-05-11   20.92     NaN     NaN     NaN     NaN     NaN
# 2 2017-05-12   20.92     NaN     NaN     NaN     NaN     NaN
# 3 2017-05-15   20.92     NaN     NaN     NaN     NaN     NaN
# 4 2017-05-16   20.92     NaN     NaN     NaN     NaN     NaN

# %%
df_lithium_returns = df_lithium.drop(columns=['Date']).pct_change()

# Plot correlation heatmap
import seaborn as sns
import matplotlib.pyplot as plt
corr_matrix_lithium = df_lithium_returns.corr()

start_date = df_lithium['Date'].min().strftime('%Y-%m-%d')
end_date = df_lithium['Date'].max().strftime('%Y-%m-%d')
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_lithium, annot=True, cmap='RdYlGn', center=0, fmt=".2f")
plt.title('Correlation Heatmap of Lithium Price Returns\nfrom {} to {}'.format(start_date, end_date))
plt.show()
# Out:
# /var/folders/mx/rb01m4j51yzbjz0dxm6z_2r80000gn/T/ipykernel_97751/123109072.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_lithium_returns = df_lithium.drop(columns=['Date']).pct_change()

# %% [markdown]
# ## Nickel

# %%
# Load nickel data
df_nickel = pd.read_csv('data/ALL_nickel_prices_cubic_spline.csv')
df_nickel['Date'] = pd.to_datetime(df_nickel['Date'])
df_nickel.head()
# Out:
#         Date  NIDALY  NILMEX  NIETFN  NISHFE  NIWUXI  NIINDA
# 0 2016-04-04     NaN  8365.0     NaN     NaN     NaN     NaN
# 1 2016-04-05     NaN  8480.0     NaN     NaN     NaN     NaN
# 2 2016-04-06     NaN  8590.0     NaN     NaN     NaN     NaN
# 3 2016-04-07     NaN  8390.0     NaN     NaN     NaN     NaN
# 4 2016-04-08     NaN  8545.0     NaN     NaN     NaN     NaN

# %%
df_nickel_returns = df_nickel.drop(columns=['Date']).pct_change()

corr_matrix_nickel = df_nickel_returns.corr()
start_date = df_nickel['Date'].min().strftime('%Y-%m-%d')
end_date = df_nickel['Date'].max().strftime('%Y-%m-%d')
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_nickel, annot=True, cmap='RdYlGn', center=0, fmt=".2f")
plt.title('Correlation Heatmap of Nickel Prices (cubic spline interpolated)\nfrom {} to {}'.format(start_date, end_date))
plt.show()
# Out:
# /var/folders/mx/rb01m4j51yzbjz0dxm6z_2r80000gn/T/ipykernel_97751/452758484.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_nickel_returns = df_nickel.drop(columns=['Date']).pct_change()

# %% [markdown]
# ## Cobalt

# %%
# Load cobalt data
df_cobalt = pd.read_csv('data/ALL_cobalt_prices_cubic_spline.csv')
df_cobalt['Date'] = pd.to_datetime(df_cobalt['Date'])
# only dates until end of 2024
#df_cobalt = df_cobalt[df_cobalt['Date'] <= '2024-12-31']
#df_cobalt = df_cobalt[df_cobalt['Date'] >= '2017-01-03']
df_cobalt.head()
# Out:
#         Date  CODALY   COLMEX  COLME3  COLMEA  COWUXI  COCOMX
# 0 2012-03-02     NaN  29900.0     NaN     NaN     NaN     NaN
# 1 2012-03-05     NaN  29405.0     NaN     NaN     NaN     NaN
# 2 2012-03-06     NaN  31250.0     NaN     NaN     NaN     NaN
# 3 2012-03-07     NaN  30925.0     NaN     NaN     NaN     NaN
# 4 2012-03-08     NaN  29925.0     NaN     NaN     NaN     NaN

# %%
df_cobalt_returns = df_cobalt.drop(columns=['Date']).pct_change()

corr_matrix_cobalt = df_cobalt_returns.corr()
start_date = df_cobalt['Date'].min().strftime('%Y-%m-%d')
end_date = df_cobalt['Date'].max().strftime('%Y-%m-%d')
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_cobalt, annot=True, cmap='RdYlGn', center=0, fmt=".2f")
plt.title('Correlation Heatmap of Cobalt Prices (cubic spline interpolated)\nfrom {} to {}'.format(start_date, end_date))
plt.show()
# Out:
# /var/folders/mx/rb01m4j51yzbjz0dxm6z_2r80000gn/T/ipykernel_97751/3328773186.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_cobalt_returns = df_cobalt.drop(columns=['Date']).pct_change()

# %% [markdown]
# ## Copper

# %%
# Load copper data
df_copper = pd.read_csv('data/ALL_copper_prices_cubic_spline.csv')
df_copper['Date'] = pd.to_datetime(df_copper['Date'])
df_copper.head()
# Out:
#         Date  CUDALY  CUCOMX  CULMEX   CUSMMG   CUSHFE  CUETFC
# 0 2017-01-01     NaN     NaN     NaN  51420.0      NaN     NaN
# 1 2017-01-03  2.4810    2.48  5500.0  45710.0  45780.0     NaN
# 2 2017-01-04  2.5480    2.55  5644.0  44770.0  45000.0     NaN
# 3 2017-01-05  2.5295    2.53  5580.0  45510.0  45560.0     NaN
# 4 2017-01-06  2.5380    2.54  5590.0  45195.0  45160.0     NaN

# %%
df_copper_returns = df_copper.drop(columns=['Date']).pct_change()

corr_matrix_copper = df_copper_returns.corr()
start_date = df_copper['Date'].min().strftime('%Y-%m-%d')
end_date = df_copper['Date'].max().strftime('%Y-%m-%d')
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_copper, annot=True, cmap='RdYlGn', center=0, fmt=".2f")
plt.title('Correlation Heatmap of Copper Prices (cubic spline interpolated)\nfrom {} to {}'.format(start_date, end_date))
plt.show()
# Out:
# /var/folders/mx/rb01m4j51yzbjz0dxm6z_2r80000gn/T/ipykernel_97751/637180941.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_copper_returns = df_copper.drop(columns=['Date']).pct_change()
